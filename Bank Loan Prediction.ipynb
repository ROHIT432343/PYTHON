# %%
import pandas as pd

# %%
loan_data=pd.read_csv('DS1_C4_S3_Loan_Data_Challenge.csv')

# %%
loan_data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_data.shape
print("\nChecking for null values:")
print(loan_data.isnull().sum())
# Out:
# Checking for null values:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ###### task 2

# %%
# Filter the DataFrame based on the conditions
filtered_data = loan_data[(loan_data['Gender'] == 'Female') & 
                          (loan_data['Self_Employed'] == 'Yes') & 
                          (loan_data['ApplicantIncome'] > 4000)]

# Display the filtered data
print("List of female customers who are self-employed and have an income greater than 4000:")
print(filtered_data)
# Out:
# List of female customers who are self-employed and have an income greater than 4000:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# ...

# %% [markdown]
# ###### task 3

# %%
# Assuming the DataFrame is already loaded and named loan_data
# Filter the DataFrame based on the conditions
filtered_data = loan_data[(loan_data['Gender'] == 'Male') & 
                          (loan_data['Education'] == 'Graduate') & 
                          (loan_data['Loan_Status'] == 'Y')]

# Display the information of these customers
print("Information of male customers with a graduate degree and loan status 'Y':")
print(filtered_data)

# Display the count of these customers
count_of_customers = len(filtered_data)
print("\nCount of male customers with a graduate degree and loan status 'Y':", count_of_customers)
# Out:
# Information of male customers with a graduate degree and loan status 'Y':
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ##### task 4

# %%
# Assuming the DataFrame is already loaded and named loan_data
# Filter the DataFrame based on the conditions
filtered_data = loan_data[(loan_data['Loan_Status'] == 'Y') & 
                          (loan_data['Dependents'].astype(str).apply(lambda x: x.isdigit() and int(x) >= 3)) & 
                          (loan_data['Property_Area'] == 'Rural')]

# Display the information of these customers
print("Information of customers with loan status 'Y', three or more dependents, and property in Rural area:")
print(filtered_data)

# Display the count of these customers
count_of_customers = len(filtered_data)
print("\nCount of customers with loan status 'Y', three or more dependents, and property in Rural area:", count_of_customers)
# Out:
# Information of customers with loan status 'Y', three or more dependents, and property in Rural area:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []
#
# Count of customers with loan status 'Y', three or more dependents, and property in Rural area: 0

# %% [markdown]
# ###### task 5

# %%
# Create a dictionary with Warner Kim's details
new_customer_data = {
    'Loan_ID': 'LP_NEW001',
    'Gender': 'Male',  # You need to provide the gender information
    'Married': 'No',  # You need to provide the marital status information
    'Dependents': 0,  # You need to provide the number of dependents
    'Education': 'Graduate',
    'Self_Employed': 'No',  # You need to provide the employment information
    'ApplicantIncome': 0,  # You need to provide the applicant's income
    'CoapplicantIncome': 0,  # You need to provide the co-applicant's income
    'LoanAmount': 290000,
    'Loan_Amount_Term': 360,
    'Credit_History': 1,  # You need to provide the credit history information
    'Property_Area': 'Urban',
    'Loan_Status': 'Y'  # This will be the predicted value
}

# Append the new customer data to the DataFrame
loan_data = loan_data.append(new_customer_data, ignore_index=True)

# Display the updated DataFrame
print("Updated DataFrame with Warner Kim's data:")
print(loan_data.tail())

# Use machine learning model or rules to predict loan approval for Warner Kim
# You can replace the following line with your actual model prediction
predicted_loan_status = 'Y'  # Placeholder for the prediction

# Display the predicted loan status for Warner Kim
print("\nPredicted Loan Status for Warner Kim:", predicted_loan_status)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16800\3959659123.py in ?()
#      15     'Loan_Status': 'Y'  # This will be the predicted value
#      16 }
#      17
#      18 # Append the new customer data to the DataFrame
# ---> 19 loan_data = loan_data.append(new_customer_data, ignore_index=True)
#      20
#      21 # Display the updated DataFrame
#      22 print("Updated DataFrame with Warner Kim's data:")
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import pandas as pd

# Assuming the DataFrame is already loaded and named loan_data

# Create a DataFrame with Warner Kim's details
new_customer_df = pd.DataFrame([new_customer_data])

# Append the new customer data to the original DataFrame
loan_data = pd.concat([loan_data, new_customer_df], ignore_index=True)

# Display the updated DataFrame
print("Updated DataFrame with Warner Kim's data:")
print(loan_data.tail())
# Out:
# Updated DataFrame with Warner Kim's data:
#        Loan_ID  Gender Married Dependents Education Self_Employed  \
# 610   LP002979    Male     Yes         3+  Graduate            No
# 611   LP002983    Male     Yes          1  Graduate            No
# 612   LP002984    Male     Yes          2  Graduate            No
# 613   LP002990  Female      No          0  Graduate           Yes
# 614  LP_NEW001    Male      No          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 610             4106                0.0          40               180
# 611             8072              240.0         253               360
# 612             7583                0.0         187               360
# 613             4583                0.0         133               360
# 614                0                0.0      290000               360
#
#      Credit_History Property_Area Loan_Status
# 610               1         Rural           Y
# ...

# %%
# Filter the DataFrame based on the conditions
filtered_data = loan_data[(loan_data['Married'] == 'No') & 
                          (loan_data['Self_Employed'] == 'Yes') & 
                          (loan_data['Property_Area'] != 'Urban') & 
                          (loan_data['Loan_Status'] == 'N')]

# Display the information of customers who meet the conditions
print("Information of customers who are not married, self-employed, live in non-urban area, and have loan status 'N':")
print(filtered_data)

# Calculate and display the gender-wise count of such customers
gender_count = filtered_data['Gender'].value_counts()
print("\nGender-wise count of customers:")
print(gender_count)
# Out:
# Information of customers who are not married, self-employed, live in non-urban area, and have loan status 'N':
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 32   LP001097    Male      No          1      Graduate           Yes
# 107  LP001370    Male      No          0  Not Graduate           Yes
# 286  LP001925  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 410  LP002318  Female      No          1  Not Graduate           Yes
# 449  LP002444    Male      No          1  Not Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 32              4692                0.0         106               360
# 107             7333                0.0         120               360
# 286             2600             1717.0          99               300
# ...

# %% [markdown]
# ##### task 7

# %%
# Assuming the DataFrame is already loaded and named loan_data

# Calculate the average income based on each property area
average_income_by_area = loan_data.groupby('Property_Area')['ApplicantIncome'].mean()

# Display the average income based on each property area
print("Average income of customers based on each property area:")
print(average_income_by_area)
# Out:
# Average income of customers based on each property area:
# Property_Area
# Rural        5554.083799
# Semiurban    5292.261803
# Urban        5371.655172
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# ###### task 8

# %%
# Step 1: List customers who have property in a rural or semiurban area, applicant income > 4000,
# co-applicant income > 1000, and loan status is 'N'
filtered_customers = loan_data[
    ((loan_data['Property_Area'] == 'Rural') | (loan_data['Property_Area'] == 'Semiurban')) &
    (loan_data['ApplicantIncome'] > 4000) &
    (loan_data['CoapplicantIncome'] > 1000) &
    (loan_data['Loan_Status'] == 'N')
]

# Display information of customers meeting the conditions
print("Customers meeting the conditions:")
print(filtered_customers)
# Count the number of such customers
count_before_update = len(filtered_customers)
print("\nNumber of customers meeting the conditions before update:", count_before_update)

# Step 2: Update the loan status of these customers to 'Y'
loan_data.loc[filtered_customers.index, 'Loan_Status'] = 'Y'

# Step 3: Verify that the count of such customers is now zero
filtered_customers_after_update = loan_data[
    ((loan_data['Property_Area'] == 'Rural') | (loan_data['Property_Area'] == 'Semiurban')) &
    (loan_data['ApplicantIncome'] > 4000) &
    (loan_data['CoapplicantIncome'] > 1000) &
    (loan_data['Loan_Status'] == 'N')
]
# Count the number of such customers after the update
count_after_update = len(filtered_customers_after_update)
print("\nNumber of customers meeting the conditions after update:", count_after_update)

# Display the updated DataFrame
print("\nUpdated DataFrame:")
print(loan_data)
# Out:
# Customers meeting the conditions:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 65   LP001225    Male     Yes          0      Graduate            No
# 83   LP001273    Male     Yes          0      Graduate            No
# 118  LP001421    Male     Yes          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 139  LP001493    Male     Yes          2  Not Graduate            No
# 140  LP001497    Male     Yes          2      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 177  LP001610    Male     Yes         3+      Graduate            No
# 258  LP001859    Male     Yes          0      Graduate            No
# ...

# %% [markdown]
# ###### task 9

# %%
# Filter the DataFrame based on the conditions
filtered_customers = loan_data[
    (loan_data['Dependents'] == '3+') &
    (loan_data['Property_Area'] == 'Urban') &
    (loan_data['Loan_Status'] == 'Y')
]

# Display information of customers meeting the conditions
print("Customers meeting the conditions:")
print(filtered_customers)

# Calculate the average income of customers meeting the conditions
average_income = filtered_customers['ApplicantIncome'].mean()
# Count the number of customers meeting the conditions
count_of_customers = len(filtered_customers)

# Display the average income and count
print("\nAverage income of customers with 3+ dependents, living in an urban area, and loan status 'Y':", average_income)
print("Number of customers meeting the conditions:", count_of_customers)
# Out:
# Customers meeting the conditions:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 61   LP001206   Male     Yes         3+      Graduate            No
# 68   LP001238   Male     Yes         3+  Not Graduate           Yes
# 171  LP001585   Male     Yes         3+      Graduate            No
# 267  LP001882   Male     Yes         3+      Graduate            No
# 295  LP001949   Male     Yes         3+      Graduate            No
# 461  LP002484   Male     Yes         3+      Graduate            No
# 531  LP002720   Male     Yes         3+      Graduate            No
# 602  LP002953   Male     Yes         3+      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 61              3029                0.0          99               360
# 68              7100                0.0         125                60
# 171            51763                0.0         700               300
# ...

# %% [markdown]
# ###### task 10

# %%
# Assuming the DataFrame is already loaded and named loan_data

# Step 1: Calculate the average income of customers living in an urban area
average_urban_income = loan_data[loan_data['Property_Area'] == 'Urban']['ApplicantIncome'].mean()

# Step 2: Filter customers who live in rural or semiurban areas, have 3+ dependents,
# and have income greater than the average income of urban customers
filtered_customers = loan_data[
    ((loan_data['Property_Area'] == 'Rural') | (loan_data['Property_Area'] == 'Semiurban')) &
    (loan_data['Dependents'] == '3+') &
    (loan_data['ApplicantIncome'] > average_urban_income)
]

# Display information of customers meeting the conditions
print("Customers meeting the conditions:")
print(filtered_customers)

# Step 3: Identify an important parameter that the bank may be using to approve the loan
# In this case, it appears that income is a key parameter, as it is being compared to the average income in an urban area.

# Step 4: Display the average applicant income of customers from non-urban areas with loan status 'Y'
average_non_urban_income = loan_data[(loan_data['Property_Area'] != 'Urban') & (loan_data['Loan_Status'] == 'Y')]['ApplicantIncome'].mean()

# Display the average applicant income
print("\nAverage applicant income of customers from non-urban areas with loan status 'Y':", average_non_urban_income)
# Out:
# Customers meeting the conditions:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 34   LP001100   Male      No         3+      Graduate            No
# 126  LP001448   Male     Yes         3+      Graduate            No
# 155  LP001536   Male     Yes         3+      Graduate            No
# 177  LP001610   Male     Yes         3+      Graduate            No
# 213  LP001715   Male     Yes         3+  Not Graduate           Yes
# 324  LP002065   Male     Yes         3+      Graduate            No
# 376  LP002219   Male     Yes         3+      Graduate            No
# 390  LP002255   Male      No         3+      Graduate            No
# 391  LP002262   Male     Yes         3+      Graduate            No
# 409  LP002317   Male     Yes         3+      Graduate            No
# 522  LP002692   Male     Yes         3+      Graduate           Yes
# 539  LP002740   Male     Yes         3+      Graduate            No
# ...
