# %% [markdown]
# ## Level 0 analysis

# %%
import matplotlib.pyplot as plt
from tabulate import tabulate
import matplotlib as mat
import seaborn as sns
import pandas as pd
import numpy as np

# %%
 df=pd.read_excel('DS1_C5_S2_Income_Data_Challenge.xlsx')

# %%
df
# Out:
#        Age   WorkClass    Education  Education_Num       Marital_Status  \
# 0       39   State-gov    Bachelors             13        Never-married
# 1       50    Self-emp    Bachelors             13   Married-civ-spouse
# 2       38     Private      HS-grad              9             Divorced
# 3       53     Private         11th              7   Married-civ-spouse
# 4       28     Private    Bachelors             13   Married-civ-spouse
# ...    ...         ...          ...            ...                  ...
# 32556   27     Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40     Private      HS-grad              9   Married-civ-spouse
# 32558   58     Private      HS-grad              9              Widowed
# 32559   22     Private      HS-grad              9        Never-married
# 32560   52    Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
df.shape
# Out:
# (32561, 11)

# %%
df.columns
# Out:
# Index(['Age', 'WorkClass', 'Education', 'Education_Num', 'Marital_Status',
#        'Occupation', 'Relationship', 'Gender', 'Hours_Per_Week',
#        'Native_Country', 'Income_Bracket'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Education       32561 non-null  object
#  3   Education_Num   32561 non-null  int64
#  4   Marital_Status  32561 non-null  object
#  5   Occupation      32561 non-null  object
#  6   Relationship    32561 non-null  object
#  7   Gender          32561 non-null  object
#  8   Hours_Per_Week  32561 non-null  int64
#  9   Native_Country  32561 non-null  object
#  10  Income_Bracket  32561 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 2.7+ MB

# %%
df.isnull().sum()# no any null value in this data frame
# Out:
# Age               0
# WorkClass         0
# Education         0
# Education_Num     0
# Marital_Status    0
# Occupation        0
# Relationship      0
# Gender            0
# Hours_Per_Week    0
# Native_Country    0
# Income_Bracket    0
# dtype: int64

# %%
df.head()
# Out:
#    Age   WorkClass   Education  Education_Num       Marital_Status  \
# 0   39   State-gov   Bachelors             13        Never-married
# 1   50    Self-emp   Bachelors             13   Married-civ-spouse
# 2   38     Private     HS-grad              9             Divorced
# 3   53     Private        11th              7   Married-civ-spouse
# 4   28     Private   Bachelors             13   Married-civ-spouse
#
#            Occupation    Relationship   Gender  Hours_Per_Week  \
# 0        Adm-clerical   Not-in-family     Male              40
# 1     Exec-managerial         Husband     Male              13
# 2   Handlers-cleaners   Not-in-family     Male              40
# 3   Handlers-cleaners         Husband     Male              40
# 4      Prof-specialty            Wife   Female              40
#
#    Native_Country Income_Bracket
# 0   United-States          <=50K
# 1   United-States          <=50K
# 2   United-States          <=50K
# 3   United-States          <=50K
# ...

# %%
df.tail()
# Out:
#        Age  WorkClass    Education  Education_Num       Marital_Status  \
# 32556   27    Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40    Private      HS-grad              9   Married-civ-spouse
# 32558   58    Private      HS-grad              9              Widowed
# 32559   22    Private      HS-grad              9        Never-married
# 32560   52   Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation Relationship   Gender  Hours_Per_Week  \
# 32556        Tech-support         Wife   Female              38
# 32557   Machine-op-inspct      Husband     Male              40
# 32558        Adm-clerical    Unmarried   Female              40
# 32559        Adm-clerical    Own-child     Male              20
# 32560     Exec-managerial         Wife   Female              40
#
#        Native_Country Income_Bracket
# 32556   United-States          <=50K
# 32557   United-States           >50K
# 32558   United-States          <=50K
# ...

# %% [markdown]
# ## level 1 analysis

# %%
def info_data_types(df):
    categorical=[]
    continuous=[]
    for i in df.columns:
        if df[i].nunique()>50:
            continuous.append(i)
        else:
            categorical.append(i)
    return categorical,continuous
categorical,continuous=info_data_types(df)
table=["categorical","continuous"]
print(tabulate({"categorical":categorical,"continuous":continuous},headers=["categorical","continuous"]))
# Out:
# categorical     continuous
# --------------  --------------
# WorkClass       Age
# Education       Hours_Per_Week
# Education_Num
# Marital_Status
# Occupation
# Relationship
# Gender
# Native_Country
# Income_Bracket

# %%
categorical
# Out:
# ['WorkClass',
#  'Education',
#  'Education_Num',
#  'Marital_Status',
#  'Occupation',
#  'Relationship',
#  'Gender',
#  'Native_Country',
#  'Income_Bracket']

# %%
continuous
# Out:
# ['Age', 'Hours_Per_Week']

# %% [markdown]
# ## task 2

# %% [markdown]
# #### Preform bivariate and multivirate analysis and on categorical column with the help of graph and charts.

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=df['WorkClass'],hue=df['Income_Bracket'])
plt.show()

# %% [markdown]
# #### interpretetion:- the data set indicate that privet sector employees <50k salary  compare to other and more then 50k salary from others .

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=df['Education'],hue=df['Income_Bracket'])
plt.show()

# %% [markdown]
# ### interpretation:-the data set indicate that the count of hs-grad is more in income_bracket<=50

# %%
fig,ax=plt.subplots(figsize=(15,7))
sns.countplot(x=df['Marital_Status'],hue=df['Income_Bracket'])
plt.show()

# %% [markdown]
# ### interpritation:- the dataset indicate that maximum nevwr maried employees salary <=50k compere to other.

# %%
fig,ax=plt.subplots(figsize=(20,7))
sns.countplot(x=df['Occupation'],hue=df['Income_Bracket'])
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,7))
sns.countplot(x=df['Relationship'],hue=df['Income_Bracket'])
plt.show()

# %% [markdown]
# ## interpritation:- the dataset indicate that maximun husbands income <=50k compere to other .

# %%
fig,ax=plt.subplots(figsize=(20,7))
sns.countplot(x=df['Gender'],hue=df['Income_Bracket'])
plt.show()

# %% [markdown]
# ### interpritation:- male employees income more then  female employees.

# %% [markdown]
# #### further analysis

# %% [markdown]
# ##### 1 check the gender wise income backet of age between 30 to 40
# ##### 2 check the education of the female of highest count of <=50k income backet
# ##### 3 is marital ststus is affecting on female of <=50k income backet.

# %%
df['Age']=df['Age'].astype(int)

# %%
df1=df[(df['Age']>=30)&(df['Age']<=40)]

# %%
df1
# Out:
#        Age   WorkClass      Education  Education_Num       Marital_Status  \
# 0       39   State-gov      Bachelors             13        Never-married
# 2       38     Private        HS-grad              9             Divorced
# 5       37     Private        Masters             14   Married-civ-spouse
# 8       31     Private        Masters             14        Never-married
# 10      37     Private   Some-college             10   Married-civ-spouse
# ...    ...         ...            ...            ...                  ...
# 32545   39   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 32546   37     Private     Assoc-acdm             12             Divorced
# 32551   32     Private           10th              6   Married-civ-spouse
# 32553   32     Private        Masters             14        Never-married
# 32557   40     Private        HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
fig,ax=plt.subplots(figsize=(20,7))
sns.countplot(x=df1['Gender'],hue=df1['Income_Bracket'])
plt.show()

# %% [markdown]
# #### interpritation:- the data set indicate that highest count of male those salary less then 50k and greater then 50k compere to female .

# %%
df2=df1[df1['Gender']==' Female']

# %%
df2
# Out:
#        Age   WorkClass      Education  Education_Num       Marital_Status  \
# 5       37     Private        Masters             14   Married-civ-spouse
# 8       31     Private        Masters             14        Never-married
# 71      31     Private      Bachelors             13            Separated
# 91      37     Private   Some-college             10             Divorced
# 93      30     Private        HS-grad              9   Married-civ-spouse
# ...    ...         ...            ...            ...                  ...
# 32536   34     Private      Bachelors             13        Never-married
# 32538   38     Private      Bachelors             13             Divorced
# 32544   31     Private        Masters             14             Divorced
# 32545   39   Local-gov     Assoc-acdm             12   Married-civ-spouse
# 32546   37     Private     Assoc-acdm             12             Divorced
#
#              Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
fig,ax=plt.subplots(figsize=(20,7))
sns.countplot(x=df2['Education'],hue=df2['Income_Bracket'])
plt.show()

# %% [markdown]
# ### interpretation:-The dataset indicate that  education wise income of  females is in hs_grad highest compere to other.

# %%
df3=df2[df2['Education']==' HS-grad']

# %%
df3
# Out:
#        Age   WorkClass Education  Education_Num       Marital_Status  \
# 93      30     Private   HS-grad              9   Married-civ-spouse
# 108     31   Local-gov   HS-grad              9        Never-married
# 114     36     Private   HS-grad              9        Never-married
# 145     31     Private   HS-grad              9        Never-married
# 147     36     Private   HS-grad              9              Widowed
# ...    ...         ...       ...            ...                  ...
# 32434   34     Private   HS-grad              9        Never-married
# 32491   33     Private   HS-grad              9             Divorced
# 32497   34     Private   HS-grad              9        Never-married
# 32509   32     Private   HS-grad              9            Separated
# 32528   31     Private   HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# 93                  Sales            Wife   Female              35
# ...

# %%
fig,ax=plt.subplots(figsize=(20,7))
sns.countplot(x=df3['Marital_Status'],hue=df3['Income_Bracket'])
plt.show()

# %% [markdown]
# #### interpretation:- The data sets indicate that these employees have an education background hs grad and income<=50k, these numbers of marital status divorces are higher than others.

# %%
df
# Out:
#        Age   WorkClass    Education  Education_Num       Marital_Status  \
# 0       39   State-gov    Bachelors             13        Never-married
# 1       50    Self-emp    Bachelors             13   Married-civ-spouse
# 2       38     Private      HS-grad              9             Divorced
# 3       53     Private         11th              7   Married-civ-spouse
# 4       28     Private    Bachelors             13   Married-civ-spouse
# ...    ...         ...          ...            ...                  ...
# 32556   27     Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40     Private      HS-grad              9   Married-civ-spouse
# 32558   58     Private      HS-grad              9              Widowed
# 32559   22     Private      HS-grad              9        Never-married
# 32560   52    Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.boxplot(y=df['Hours_Per_Week'],hue=df['Income_Bracket'])
sns.countplot(x=df['Hours_Per_Week'],hue=df['Income_Bracket'],ax=ax[0])
plt.show()

# %%
m=df['Hours_Per_Week'].mean()

# %%
x=df[(df['Hours_Per_Week']>=46) | (df['Hours_Per_Week']<=35)].index

# %%
x
# Out:
# Index([    1,     6,     8,    10,    12,    13,    16,    18,    20,    21,
#        ...
#        32539, 32541, 32542, 32543, 32544, 32545, 32548, 32550, 32553, 32559],
#       dtype='int64', length=14019)

# %%
for i in x:
    df.loc[i,'Hours_Per_Week']=m

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
sns.boxplot(y=df['Hours_Per_Week'],hue=df['Income_Bracket'])
sns.countplot(x=df['Hours_Per_Week'],hue=df['Income_Bracket'],ax=ax[0])
plt.show()

# %% [markdown]
# ### interpretation:- hte workers who are working between 40 to 42 hours per week are taking <=50k and >=50k income bracket.

# %%
df.columns
# Out:
# Index(['Age', 'WorkClass', 'Education', 'Education_Num', 'Marital_Status',
#        'Occupation', 'Relationship', 'Gender', 'Hours_Per_Week',
#        'Native_Country', 'Income_Bracket'],
#       dtype='object')
