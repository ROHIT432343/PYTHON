# %% [markdown]
# #### task 1

# %%
import matplotlib.pyplot as plt
from tabulate import tabulate
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib as mat

# %%
df= pd.read_csv('DS1_C5_S1_EmployeeAttrition_Data_Practice.csv')

# %%
print('pandas version:',pd.__version__)
print('numpy version:',np.__version__)
print('matplotlib version:',mat.__version__)
# Out:
# pandas version: 2.0.3
# numpy version: 1.24.3
# matplotlib version: 3.7.2

# %%
df.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 0  41.0       Yes      Travel_Rarely                   Sales
# 1  49.0        No  Travel_Frequently  Research & Development
# 2  37.0       Yes      Travel_Rarely  Research & Development
# 3  33.0        No  Travel_Frequently  Research & Development
# 4  27.0        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# 0                 1  Life Sciences               1                        2
# 1                 8  Life Sciences               2                        3
# 2                 2          Other               4                        4
# 3                 3  Life Sciences               5                        4
# 4                 2        Medical               7                        1
#
#    Gender  HourlyRate  ...  OverTime PerformanceRating  \
# 0  Female          94  ...       Yes                 3
# ...

# %%
df.tail()
# Out:
#        Age Attrition     BusinessTravel              Department  \
# 1465  36.0        No                NaN  Research & Development
# 1466  39.0        No      Travel_Rarely  Research & Development
# 1467  27.0        No      Travel_Rarely  Research & Development
# 1468  49.0        No  Travel_Frequently                   Sales
# 1469  34.0        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome EducationField  EmployeeNumber  \
# 1465                23        Medical            2061
# 1466                 6        Medical            2062
# 1467                 4  Life Sciences            2064
# 1468                 2        Medical            2065
# 1469                 8        Medical            2068
#
#       EnvironmentSatisfaction Gender  HourlyRate  ...  OverTime  \
# 1465                        3   Male          41  ...        No
# 1466                        4   Male          42  ...        No
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1446 non-null   float64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1440 non-null   object
#  3   Department                1466 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   EducationField            1458 non-null   object
#  6   EmployeeNumber            1470 non-null   int64
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1425 non-null   object
#  9   HourlyRate                1470 non-null   int64
#  10  JobInvolvement            1470 non-null   int64
#  11  JobRole                   1460 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel              30
# Department                   4
# DistanceFromHome             0
# EducationField              12
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                      45
# HourlyRate                   0
# JobInvolvement               0
# JobRole                     10
# JobSatisfaction              0
# MaritalStatus               56
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                      54
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PerformanceRating', 'RelationshipSatisfaction',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
def seprete_data_types(df):
    categorical = []
    continuous = []
    for column in df.columns:
        if df[column].nunique()>10:
            continuous.append(column)
        else:
            categorical.append(column)
    return categorical,continuous
categorical,continuous=seprete_data_types(df)
table=[categorical,continuous]
print(tabulate({"categorical":categorical,"continuous":continuous},headers=["categorical","continuous"]))
# Out:
# categorical               continuous
# ------------------------  -----------------------
# Attrition                 Age
# BusinessTravel            DistanceFromHome
# Department                EmployeeNumber
# EducationField            HourlyRate
# EnvironmentSatisfaction   MonthlyIncome
# Gender                    TotalWorkingYears
# JobInvolvement            YearsAtCompany
# JobRole                   YearsInCurrentRole
# JobSatisfaction           YearsSinceLastPromotion
# MaritalStatus             YearsWithCurrManager
# NumCompaniesWorked
# Over18
# OverTime
# PerformanceRating
# RelationshipSatisfaction
# TrainingTimesLastYear
# WorkLifeBalance

# %%
print(categorical)
# Out:
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PerformanceRating', 'RelationshipSatisfaction', 'TrainingTimesLastYear', 'WorkLifeBalance']

# %%
print(continuous)
# Out:
# ['Age', 'DistanceFromHome', 'EmployeeNumber', 'HourlyRate', 'MonthlyIncome', 'TotalWorkingYears', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %% [markdown]
# ###### task 3

# %%
 def info_of_cat(col):
         print(f"unique value in {col}are:{df[col].unique()}")
         print(f"mode of {col} is:{df[col].mode()[0]}")
         print(f"number of missing value{col} in:{df[col].isnull().sum()}")

# %%
info_of_cat('Attrition')
# Out:
# unique value in Attritionare:['Yes' 'No']
# mode of Attrition is:No
# number of missing valueAttrition in:0

# %%
info_of_cat('BusinessTravel')
# Out:
# unique value in BusinessTravelare:['Travel_Rarely' 'Travel_Frequently' 'Non-Travel' nan]
# mode of BusinessTravel is:Travel_Rarely
# number of missing valueBusinessTravel in:30

# %%
# for filling the missing value 
bissness_traval_mode=df.BusinessTravel.mode()[0]
print(bissness_traval_mode)
df["BusinessTravel"].fillna(bissness_traval_mode,inplace=True)
# Out:
# Travel_Rarely

# %%
df.isnull().sum()
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel               0
# Department                   4
# DistanceFromHome             0
# EducationField              12
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                      45
# HourlyRate                   0
# JobInvolvement               0
# JobRole                     10
# JobSatisfaction              0
# MaritalStatus               56
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                      54
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %%
info_of_cat("Department")
# Out:
# unique value in Departmentare:['Sales' 'Research & Development' 'Human Resources' nan]
# mode of Department is:Research & Development
# number of missing valueDepartment in:4

# %%
# for filling the missing value 
department_mode=df['Department'].mode()[0]
print(department_mode)
# Out:
# Research & Development

# %%
df['Department'].fillna(department_mode,inplace=True)

# %%
info_of_cat("Department")
# Out:
# unique value in Departmentare:['Sales' 'Research & Development' 'Human Resources']
# mode of Department is:Research & Development
# number of missing valueDepartment in:0

# %%
info_of_cat('Gender')
# Out:
# unique value in Genderare:['Female' 'Male' nan]
# mode of Gender is:Male
# number of missing valueGender in:45

# %%
gender_mode=df['Gender'].mode()[0]
gender_mode
# Out:
# 'Male'

# %%
df['Gender'].fillna(gender_mode,inplace=True)

# %%
info_of_cat('MaritalStatus')
# Out:
# unique value in MaritalStatusare:['Single' 'Married' nan 'Divorced']
# mode of MaritalStatus is:Married
# number of missing valueMaritalStatus in:56

# %%
MaritalStatus_mode=df['MaritalStatus'].mode()[0]
MaritalStatus_mode
# Out:
# 'Married'

# %%
df['MaritalStatus'].fillna(MaritalStatus_mode,inplace=True)

# %%
info_of_cat('MaritalStatus')
# Out:
# unique value in MaritalStatusare:['Single' 'Married' 'Divorced']
# mode of MaritalStatus is:Married
# number of missing valueMaritalStatus in:0

# %%
info_of_cat('Over18')
# Out:
# unique value in Over18are:['Y' nan]
# mode of Over18 is:Y
# number of missing valueOver18 in:54

# %%
Over18_mode=df['Over18'].mode()[0]
df['Over18'].fillna(Over18_mode,inplace=True)

# %%
info_of_cat('Over18')
# Out:
# unique value in Over18are:['Y']
# mode of Over18 is:Y
# number of missing valueOver18 in:0

# %%
df.isnull().sum()
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel               0
# Department                   0
# DistanceFromHome             0
# EducationField              12
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                       0
# HourlyRate                   0
# JobInvolvement               0
# JobRole                     10
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                       0
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %%
info_of_cat('EducationField')
# Out:
# unique value in EducationFieldare:['Life Sciences' 'Other' 'Medical' 'Marketing' nan 'Technical Degree'
#  'Human Resources']
# mode of EducationField is:Life Sciences
# number of missing valueEducationField in:12

# %%
EducationField_mode=df['EducationField'].mode()[0]
df['EducationField'].fillna(EducationField_mode,inplace=True)

# %%
info_of_cat('EducationField')
# Out:
# unique value in EducationFieldare:['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# mode of EducationField is:Life Sciences
# number of missing valueEducationField in:0

# %%
info_of_cat('JobRole')
# Out:
# unique value in JobRoleare:['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' nan 'Human Resources']
# mode of JobRole is:Sales Executive
# number of missing valueJobRole in:10

# %%
JobRole_mode=df['JobRole'].mode()[0]

# %%
df['JobRole'].fillna(JobRole_mode,inplace=True)

# %%
info_of_cat('JobRole')
# Out:
# unique value in JobRoleare:['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# mode of JobRole is:Sales Executive
# number of missing valueJobRole in:0

# %%
df.isnull().sum()
# Out:
# Age                         24
# Attrition                    0
# BusinessTravel               0
# Department                   0
# DistanceFromHome             0
# EducationField               0
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                       0
# HourlyRate                   0
# JobInvolvement               0
# JobRole                      0
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome                0
# NumCompaniesWorked           0
# Over18                       0
# OverTime                     0
# PerformanceRating            0
# RelationshipSatisfaction     0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# WorkLifeBalance              0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# dtype: int64

# %%
info_of_cat('Age')
# Out:
# unique value in Ageare:[41. 49. 37. 33. 27. 32. 59. 30. 38. 36. 35. 29. 31. 34. 28. 22. 53. 24.
#  21. nan 42. 44. 46. 39. 43. 50. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58.
#  20. 25. 19. 57. 52. 47. 18. 60.]
# mode of Age is:34.0
# number of missing valueAge in:24

# %%
Age_mode=df['Age'].mode()[0]
df['Age'].fillna(Age_mode,inplace=True)

# %%
info_of_cat('Age')
# Out:
# unique value in Ageare:[41. 49. 37. 33. 27. 32. 59. 30. 38. 36. 35. 29. 31. 34. 28. 22. 53. 24.
#  21. 42. 44. 46. 39. 43. 50. 26. 48. 55. 45. 56. 23. 51. 40. 54. 58. 20.
#  25. 19. 57. 52. 47. 18. 60.]
# mode of Age is:34.0
# number of missing valueAge in:0

# %% [markdown]
# ##### task 4

# %% [markdown]
# Perform discriptive analysis of all the categorical column with the help of univariate chart/graph

# %%
# visual presentation of attrition attribute
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("count of Attrition")
percentage=df["Attrition"].value_counts()
labels=list(df["Attrition"].value_counts().index)
sns.countplot(x=df["Attrition"],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:- the data set indicate that 16% employees attrition is yes while 84 % yes  still its .

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("count of Attrition")
percentage=df["Attrition"].value_counts()
lebels=list(df["Attrition"].value_counts().index)
sns.countplot(x=df["Attrition"],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:-the data set indicate that  84%of the employee are still the company while 16% of employee are left with it .

# %%
fig,ax=plt.subplots(1,2,figsize=(15,5))
ax[0].set_title("count of business")
percentage=df["BusinessTravel"].value_counts()
labels=list(df["BusinessTravel"].value_counts().index)
sns.countplot(x=df["BusinessTravel"],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:- the data set indicates that 72% employees in company who trevels rarely but 18% employees travels frequently while 10% employee do not any experience of traveling.

# %%
# visual presentation of department attribute 
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of departments')
percentage=df['Department'].value_counts()
labels=list(df['Department'].value_counts().index)
sns.countplot(x=df["Department"], ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:- the data set indicate that 66% employee working in research and devlopment department .

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of MaritalStatus')
percentage=df['MaritalStatus'].value_counts()
labels=list(df['MaritalStatus'].value_counts().index)
sns.countplot(x=df['MaritalStatus'],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:-the data set indicate that 43% employee are married  and unmarried employee 31% while divorced 22%.

# %%
# visual presentation EducationField attrition attribute
info_of_cat('EducationField')
# Out:
# unique value in EducationFieldare:['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# mode of EducationField is:Life Sciences
# number of missing valueEducationField in:0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("count of EducationField")
percentage=df['EducationField'].value_counts()
labels=list(df['EducationField'].value_counts().index)
sns.countplot(x=df['EducationField'],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:- the data set indicate that maximum number of employee belongs from life science education field .minimum number of employee associated with human resorces that is 2%  only of total employee.

# %%
info_of_cat('EnvironmentSatisfaction')
# Out:
# unique value in EnvironmentSatisfactionare:[2 3 4 1]
# mode of EnvironmentSatisfaction is:3
# number of missing valueEnvironmentSatisfaction in:0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("count of EnvironmentSatisfaction")
percentage=df['EnvironmentSatisfaction'].value_counts()
labels=list(df['EnvironmentSatisfaction'].value_counts().index)
sns.countplot(x=df['EnvironmentSatisfaction'],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:-the data set indicate that most of the employee in complany are setisfied up to 3 and 4 level which adds upto 34% of the total employee.

# %%
info_of_cat('OverTime')
info_of_cat('WorkLifeBalance')
info_of_cat('PerformanceRating')
# Out:
# unique value in OverTimeare:['Yes' 'No']
# mode of OverTime is:No
# number of missing valueOverTime in:0
# unique value in WorkLifeBalanceare:[1 3 2 4]
# mode of WorkLifeBalance is:3
# number of missing valueWorkLifeBalance in:0
# unique value in PerformanceRatingare:[3 4]
# mode of PerformanceRating is:3
# number of missing valuePerformanceRating in:0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("count of OverTime")
percentage=df['OverTime'].value_counts()
labels=list(df['OverTime'].value_counts().index)
sns.countplot(x=df['OverTime'],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ###### interpretation:- the data set indicate that only 29% employee working in  overtime

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("count of PerformanceRating")
percentage=df['PerformanceRating'].value_counts()
labels=list(df['PerformanceRating'].value_counts().index)
sns.countplot(x=df['PerformanceRating'],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:- the dataset indicate that most of employee rating 3.

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("count of WorkLifeBalance")
percentage=df['WorkLifeBalance'].value_counts()
labels=list(df['WorkLifeBalance'].value_counts().index)
sns.countplot(x=df['WorkLifeBalance'],ax=ax[0])
plt.pie(percentage,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation :- the data set indicate that most of the employees showing balence between work and life on 3 and 4 scale which adds upto 71% of the totel employees.

# %% [markdown]
# ##### task 5

# %%
def info_of_numerical(col):
    print(f"the mean of the {col} is {df[col].mean()}")
    print(f" the median of the {col} is {df[col].median()}")
    print(f" the mode of the {col} is {df[col].mode()[0]}")
    print(f" the standard deviation of the {col} is { df[col].std()}")
    print (f" number of missing value in the {col} is {df[col].isnull().sum()}")

# %%
info_of_numerical("Age")
# Out:
# the mean of the Age is 36.88231292517007
#  the median of the Age is 35.0
#  the mode of the Age is 34.0
#  the standard deviation of the Age is 9.094640442374576
#  number of missing value in the Age is 0

# %%
info_of_numerical("MonthlyIncome")
# Out:
# the mean of the MonthlyIncome is 6502.931292517007
#  the median of the MonthlyIncome is 4919.0
#  the mode of the MonthlyIncome is 2342
#  the standard deviation of the MonthlyIncome is 4707.956783097995
#  number of missing value in the MonthlyIncome is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title("histogram")
ax[1].set_title("boxplot")
sns.histplot(x=df["Age"],ax=ax[0])
sns.boxplot(x=df["Age"],ax=ax[1])
plt.show()

# %% [markdown]
# info_of_numerical("monthlyincome")

# %%
info_of_numerical("MonthlyIncome")
# Out:
# the mean of the MonthlyIncome is 6502.931292517007
#  the median of the MonthlyIncome is 4919.0
#  the mode of the MonthlyIncome is 2342
#  the standard deviation of the MonthlyIncome is 4707.956783097995
#  number of missing value in the MonthlyIncome is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('histrogram')
ax[1].set_title('boxplot')
sns.histplot(x=df['MonthlyIncome'],ax=ax[0])
sns.boxplot(x=df['MonthlyIncome'],ax=ax[1])
plt.show()

# %% [markdown]
# ##### interpretation:- there is a right skewness in above task

# %%
info_of_numerical("HourlyRate")
# Out:
# the mean of the HourlyRate is 65.89115646258503
#  the median of the HourlyRate is 66.0
#  the mode of the HourlyRate is 66
#  the standard deviation of the HourlyRate is 20.329427593996158
#  number of missing value in the HourlyRate is 0

# %%
fig,ax=plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('histrogram')
ax[1].set_title('boxplot')
sns.histplot(x=df['HourlyRate'],ax=ax[0])
sns.boxplot(x=df['HourlyRate'],ax=ax[1])
plt.show()

# %% [markdown]
# ##### interpretation:-there is no skewness in above task
