# %% [markdown]
# ##### task 1

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from tabulate import tabulate
import seaborn as sns
import matplotlib as mat

# %%
df=pd.read_excel('DS1_C5_S1_Income_Data_Challenge.xlsx')

# %%
df
# Out:
#        Age   WorkClass    Education  Education_Num       Marital_Status  \
# 0       39   State-gov    Bachelors             13        Never-married
# 1       50    Self-emp    Bachelors             13   Married-civ-spouse
# 2       38     Private      HS-grad              9             Divorced
# 3       53     Private         11th              7   Married-civ-spouse
# 4       28     Private    Bachelors             13   Married-civ-spouse
# ...    ...         ...          ...            ...                  ...
# 32556   27     Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40     Private      HS-grad              9   Married-civ-spouse
# 32558   58     Private      HS-grad              9              Widowed
# 32559   22     Private      HS-grad              9        Never-married
# 32560   52    Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation    Relationship   Gender  Hours_Per_Week  \
# ...

# %%
df.head()
# Out:
#    Age   WorkClass   Education  Education_Num       Marital_Status  \
# 0   39   State-gov   Bachelors             13        Never-married
# 1   50    Self-emp   Bachelors             13   Married-civ-spouse
# 2   38     Private     HS-grad              9             Divorced
# 3   53     Private        11th              7   Married-civ-spouse
# 4   28     Private   Bachelors             13   Married-civ-spouse
#
#            Occupation    Relationship   Gender  Hours_Per_Week  \
# 0        Adm-clerical   Not-in-family     Male              40
# 1     Exec-managerial         Husband     Male              13
# 2   Handlers-cleaners   Not-in-family     Male              40
# 3   Handlers-cleaners         Husband     Male              40
# 4      Prof-specialty            Wife   Female              40
#
#    Native_Country Income_Bracket
# 0   United-States          <=50K
# 1   United-States          <=50K
# 2   United-States          <=50K
# 3   United-States          <=50K
# ...

# %%
df.tail()
# Out:
#        Age  WorkClass    Education  Education_Num       Marital_Status  \
# 32556   27    Private   Assoc-acdm             12   Married-civ-spouse
# 32557   40    Private      HS-grad              9   Married-civ-spouse
# 32558   58    Private      HS-grad              9              Widowed
# 32559   22    Private      HS-grad              9        Never-married
# 32560   52   Self-emp      HS-grad              9   Married-civ-spouse
#
#                Occupation Relationship   Gender  Hours_Per_Week  \
# 32556        Tech-support         Wife   Female              38
# 32557   Machine-op-inspct      Husband     Male              40
# 32558        Adm-clerical    Unmarried   Female              40
# 32559        Adm-clerical    Own-child     Male              20
# 32560     Exec-managerial         Wife   Female              40
#
#        Native_Country Income_Bracket
# 32556   United-States          <=50K
# 32557   United-States           >50K
# 32558   United-States          <=50K
# ...

# %%
df.shape
# Out:
# (32561, 11)

# %%
df.columns
# Out:
# Index(['Age', 'WorkClass', 'Education', 'Education_Num', 'Marital_Status',
#        'Occupation', 'Relationship', 'Gender', 'Hours_Per_Week',
#        'Native_Country', 'Income_Bracket'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Education       32561 non-null  object
#  3   Education_Num   32561 non-null  int64
#  4   Marital_Status  32561 non-null  object
#  5   Occupation      32561 non-null  object
#  6   Relationship    32561 non-null  object
#  7   Gender          32561 non-null  object
#  8   Hours_Per_Week  32561 non-null  int64
#  9   Native_Country  32561 non-null  object
#  10  Income_Bracket  32561 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 2.7+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# WorkClass         0
# Education         0
# Education_Num     0
# Marital_Status    0
# Occupation        0
# Relationship      0
# Gender            0
# Hours_Per_Week    0
# Native_Country    0
# Income_Bracket    0
# dtype: int64

# %% [markdown]
# ###### task 2

# %%
def seprete_data_types(df):
    categorical=[]
    continuous=[]
    for i in df.columns:
        if df[i].nunique()>50:
            continuous.append(i)
        else:
            categorical.append(i)
    return continuous,categorical
continuous,categorical=seprete_data_types(df)
table=[continuous,categorical]
print( tabulate({"categorical":categorical,"continuous":continuous},headers=["categorical","continuous"]))
# Out:
# categorical     continuous
# --------------  --------------
# WorkClass       Age
# Education       Hours_Per_Week
# Education_Num
# Marital_Status
# Occupation
# Relationship
# Gender
# Native_Country
# Income_Bracket

# %% [markdown]
# ##### task 3

# %%
print(categorical)
# Out:
# ['WorkClass', 'Education', 'Education_Num', 'Marital_Status', 'Occupation', 'Relationship', 'Gender', 'Native_Country', 'Income_Bracket']

# %%
 def info_of_cat(col):
         print(f"unique value in {col}are:{df[col].unique()}")
         print(f"mode of {col} is:{df[col].mode()[0]}")
         print(f"number of missing value{col} in:{df[col].isnull().sum()}")

# %%
info_of_cat('WorkClass')
# Out:
# unique value in WorkClassare:[' State-gov' 'Self-emp' ' Private' ' Federal-gov' ' Local-gov' ' ?'
#  ' Self-emp' ' Without-pay' ' Never-worked']
# mode of WorkClass is: Private
# number of missing valueWorkClass in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('number of employee based on WorkClass')
percentege=df['WorkClass'].value_counts()
labels=list(df['WorkClass'].value_counts().index)
sns.countplot(x=df['WorkClass'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation:- the data set indicate that maximum employee working in privet sector .

# %%
info_of_cat('Education')
# Out:
# unique value in Educationare:[' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# mode of Education is: HS-grad
# number of missing valueEducation in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(30,7))
ax[0].set_title('number of employee based on  Education')
percentege=df['Education'].value_counts()
labels=list(df['Education'].value_counts().index)
sns.countplot(x=df['Education'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation :- the data set indicate that 32% of the employees are hs grad and 23% employees are graduates.

# %%
info_of_cat('Education_Num')
# Out:
# unique value in Education_Numare:[13  9  7 14  5 10 12 11  4 16 15  3  6  2  1  8]
# mode of Education_Num is:9
# number of missing valueEducation_Num in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of Education_Num')
percentege=df['Education_Num'].value_counts()
labels=list(df['Education_Num'].value_counts().index)
sns.countplot(x=df['Education_Num'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %%
info_of_cat('Marital_Status')
# Out:
# unique value in Marital_Statusare:[' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# mode of Marital_Status is: Married-civ-spouse
# number of missing valueMarital_Status in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(25,7))
ax[0].set_title('count of Marital_Status')
percentege=df['Marital_Status'].value_counts()
labels=list(df['Marital_Status'].value_counts().index)
sns.countplot(x=df['Marital_Status'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation :-46% of the employees are married and whose spouse correspond to civilian spouse and 33% are unmarried employees.

# %%
info_of_cat('Occupation')
# Out:
# unique value in Occupationare:[' Adm-clerical' ' Exec-managerial' ' Handlers-cleaners' ' Prof-specialty'
#  ' Other-service' ' Sales' ' Craft-repair' ' Transport-moving'
#  ' Farming-fishing' ' Machine-op-inspct' ' Tech-support' ' ?'
#  ' Protective-serv' ' Armed-Forces' ' Priv-house-serv']
# mode of Occupation is: Prof-specialty
# number of missing valueOccupation in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(30,15))
ax[0].set_title('count of Occupation')
percentege=df['Occupation'].value_counts()
labels=list(df['Occupation'].value_counts().index)
sns.countplot(x=df['Occupation'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %%
info_of_cat('Relationship')
# Out:
# unique value in Relationshipare:[' Not-in-family' ' Husband' ' Wife' ' Own-child' ' Unmarried'
#  ' Other-relative']
# mode of Relationship is: Husband
# number of missing valueRelationship in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of Relationship')
percentege=df['Relationship'].value_counts()
labels=list(df['Relationship'].value_counts().index)
sns.countplot(x=df['Relationship'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ###### interpretation :- the data set indicate that maximum employees of hasbend in relationship.

# %%
info_of_cat('Gender')
# Out:
# unique value in Genderare:[' Male' ' Female']
# mode of Gender is: Male
# number of missing valueGender in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of Gender')
percentege=df['Gender'].value_counts()
labels=list(df['Gender'].value_counts().index)
sns.countplot(x=df['Gender'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ###### interpretation :- the data set indicate that 66% mal and 33% female.

# %%
info_of_cat('Income_Bracket')
# Out:
# unique value in Income_Bracketare:[' <=50K' ' >50K']
# mode of Income_Bracket is: <=50K
# number of missing valueIncome_Bracket in:0

# %%
fig,ax= plt.subplots(1,2,figsize=(15,7))
ax[0].set_title('count of Income_Bracket')
percentege=df['Income_Bracket'].value_counts()
labels=list(df['Income_Bracket'].value_counts().index)
sns.countplot(x=df['Income_Bracket'],ax=ax[0])
plt.pie(percentege,labels=labels,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# ##### interpretation :- the data set indicate that most of employees salary less then 50k.

# %% [markdown]
# ##### task 5

# %%
def info_of_numirical(col):
    print(f"the mean of the {col} is {df[col].mean()}")
    print(f" the median of the {col} is {df[col].median()}")
    print(f"the mode of the {col} is {df[col].mode()[0]}")
    print(f" the standerd division of the {col} is {df[col].std()}")

# %%
print(continuous)
# Out:
# ['Age', 'Hours_Per_Week']

# %%
info_of_numirical('Age')
# Out:
# the mean of the Age is 38.58164675532078
#  the median of the Age is 37.0
# the mode of the Age is 36
#  the standerd division of the Age is 13.640432553581146

# %%
info_of_numirical('Hours_Per_Week')
# Out:
# the mean of the Hours_Per_Week is 40.437455852092995
#  the median of the Hours_Per_Week is 40.0
# the mode of the Hours_Per_Week is 40
#  the standerd division of the Hours_Per_Week is 12.34742868173081

# %% [markdown]
# ##### task 6

# %%
fig,ax=plt.subplots(1,2,figsize=(20,8))
sns.histplot(x=df['Age'],ax=ax[0])
sns.boxplot(x=df['Age'],ax=ax[1])
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ##### interpretation:- for the age outlier are present some employees age are greter then 77 .most of the employee are having their age in between 28 to 49.

# %%
fig,ax=plt.subplots(1,2,figsize=(20,8))
sns.histplot(x=df['Hours_Per_Week'],ax=ax[0])
sns.boxplot(x=df['Hours_Per_Week'],ax=ax[1])
# Out:
# <Axes: xlabel='Hours_Per_Week'>

# %% [markdown]
# ##### interpretations:-for the hours per week outlier are present on both sides .most of the employees hours per week is in between 40-45
